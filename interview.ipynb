# %% [markdown]
# ## Introduction
#
# The deliverable for this Take Home is this python notebook (`.ipynb` format), updated with your code.
#
# It consists of 3 parts. If you're not able to complete certain aspects of part 1 or 2 with code, simply describe the way you would solve it.
#
# Import the following libraries to get started, installing them on your computer first if needed.
#
# Reach out if you have any queries, and have fun!

# %%
# !pip install delta_sharing
# Out:
# Collecting delta_sharing
#   Downloading delta_sharing-1.3.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting delta-kernel-rust-sharing-wrapper>=0.2.0 (from delta_sharing)
#   Downloading delta_kernel_rust_sharing_wrapper-0.2.2-cp38-abi3-manylinux_2_31_x86_64.whl.metadata (708 bytes)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from delta_sharing) (2.2.2)
# Requirement already satisfied: pyarrow>=16.1.0 in /usr/local/lib/python3.11/dist-packages (from delta_sharing) (18.1.0)
# Requirement already satisfied: fsspec>=0.7.4 in /usr/local/lib/python3.11/dist-packages (from delta_sharing) (2025.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from delta_sharing) (2.32.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from delta_sharing) (3.11.15)
# Requirement already satisfied: yarl>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from delta_sharing) (1.19.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl>=1.6.0->delta_sharing) (3.10)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.11/dist-packages (from yarl>=1.6.0->delta_sharing) (6.4.3)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl>=1.6.0->delta_sharing) (0.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->delta_sharing) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->delta_sharing) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->delta_sharing) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->delta_sharing) (1.5.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->delta_sharing) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->delta_sharing) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->delta_sharing) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->delta_sharing) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->delta_sharing) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->delta_sharing) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->delta_sharing) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->delta_sharing) (1.17.0)
# Downloading delta_sharing-1.3.2-py3-none-any.whl (29 kB)
# Downloading delta_kernel_rust_sharing_wrapper-0.2.2-cp38-abi3-manylinux_2_31_x86_64.whl (12.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 101.6 MB/s eta 0:00:00
# Installing collected packages: delta-kernel-rust-sharing-wrapper, delta_sharing
# Successfully installed delta-kernel-rust-sharing-wrapper-0.2.2 delta_sharing-1.3.2

# %% [markdown]
# ## Import Packages

# %%
import requests
import json
import pandas as pd
import delta_sharing
from io import BytesIO
from datetime import datetime

# %% [markdown]
# ## Explore config file

# %%
profile_file = "config_interview.share"
# Initiate the class
client = delta_sharing.SharingClient(profile_file)
print("List all attributes and methods in class client:", dir(client))
# check list_shares() method
for share in client.list_shares():
    print("Share:", share.name)
# check list_all_tables() method
for table in client.list_all_tables():
    print("Table", table)
    print("Table name:", table.name)
    print("Table schema:", table.schema)
    print("______________________________")
# Out:
# List all attributes and methods in class client: ['_SharingClient__list_all_tables_in_share', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_profile', '_rest_client', 'list_all_tables', 'list_schemas', 'list_shares', 'list_tables']
# Share: interview
# Table Table(name='unybiz_forms_forms', share='interview', schema='demo')
# Table name: unybiz_forms_forms
# Table schema: demo
# ______________________________
# Table Table(name='novadetrack_publicprojects', share='interview', schema='demo')
# Table name: novadetrack_publicprojects
# Table schema: demo
# ______________________________

# %% [markdown]
# ## Part 1
# Hello, fellow Data Engineer at ChopChop Construction!
#
# Data Provider Nova has stored our data on Databricks, and they've given us the following instructions.
#
# > Hi! Here's documentation on how to retrieve the data you asked for https://github.com/delta-io/delta-sharing/blob/main/PROTOCOL.md#api-response-format-in-delta. The credentials you need are in the config file sent. Our schema name is `demo` and the table names are `unybiz_forms_forms` and `novadetrack_publicprojects`.
#
#
# Your coworker has called the API and gotten a response. However, he needs help parsing the parquet file links to retrieve the tables in a pandas dataframe format. Write some code that does this and display both tables.
#
# He also removed the Bearer token so you will have to add that back in as well.

# %% [markdown]
# ## Read parquet table via API

# %%
token="YR9jlOyIg07I8ZPoF6V0kNo0lcN0zWqtNwwFOeaaYqIgY9qDwnhGP6kN61VrLp_W" #As best practice, token should be saved in KeyVault and not hard-coded here
tables = ["unybiz_forms_forms", "novadetrack_publicprojects"]
for table in tables:
    print(f"Processing table: {table}")
    url = f"https://southeastasia.azuredatabricks.net/api/2.0/delta-sharing/metastores/0f7c5957-12d6-4931-a13f-6e65314456b6/shares/interview/schemas/demo/tables/{table}/query"

    # headers is refered to Read Data from a Table Section in https://github.com/delta-io/delta-sharing/blob/main/PROTOCOL.md#list-schemas-in-a-share
    headers = {
        "Authorization": f"Bearer {token}",
        "Content-Type": "application/json; charset=utf-8", #optional
        "delta-sharing-capabilities": "responseformat=parquet" #optional
    }
    # payload is refered to Read Data from a Table Section in https://github.com/delta-io/delta-sharing/blob/main/PROTOCOL.md#example-for-snapshot-query
    payload = {
        "predicateHints": [],
        "limitHint": 0,
        "jsonPredicateHints": ""
    }
    # query_params is not required according to the above documentation
    query_params = {"": ""}
    response = requests.post(url, json=payload, headers=headers)
    #print("Response status_code:", response.status_code)
    # Remark: response.json() cannot be used because response is not valid JSON, so response.text is used instead
    print("Response text:", response.text)

    if response.status_code == 200:
        try:
            # Read the response line by line (strip is used to remove any leading whitespace in text and split each line which is separated by \n)
            list_parquet_urls = []
            for line in response.text.strip().split("\n"):
                # load each line to json format for further usage
                record = json.loads(line)
                if "metaData" in record:
                    print("Metadata (Schema of table)", record["metaData"])
                if "file" in record:
                    # append url to list_parquet_urls
                    list_parquet_urls.append(record["file"]["url"])

            if len(list_parquet_urls)==0:
                print(f"There is no parquet files in the table {table}.")
            else:
                # Use pandas read_parquet to load each parquet file into a pandas DataFrame and append it to all_tables
                all_tables = []
                for parquet_url in list_parquet_urls:
                    all_tables.append(pd.read_parquet(parquet_url))
                # Concatinate all tables
                pd_table = pd.concat(all_tables, ignore_index=True)
                print(f"Number of rows in {table} table:", pd_table.shape[0])
                display(pd_table)
        except ValueError as e:
            print(f"Error when processing table {table}: {e}")
    else:
        print(f"Failed to query table {table} -- Response status_code: {response.status_code}")
# Out:
# Processing table: unybiz_forms_forms
# Response text: {"protocol":{"minReaderVersion":1}}
# {"metaData":{"id":"425438de-09d8-4e26-9e13-a3a585c480bd","format":{"provider":"parquet"},"schemaString":"{\"type\":\"struct\",\"fields\":[{\"name\":\"id\",\"type\":\"string\",\"nullable\":false,\"metadata\":{}},{\"name\":\"date\",\"type\":\"long\",\"nullable\":true,\"metadata\":{}},{\"name\":\"geo\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"linkedid\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"linkedtable\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"name\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"owner\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"projectid\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"status\",\"type\":\"integer\",\"nullable\":true,\"metadata\":{}},{\"name\":\"history\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"templateid\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"value\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"module\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"feature\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}}]}","partitionColumns":[],"configuration":{},"size":6056266,"numFiles":8}}
# {"file":{"url":"https://asiadatastorage.dfs.core.windows.net/metastore/0f7c5957-12d6-4931-a13f-6e65314456b6/tables/9959bcb6-510a-480a-9d0b-102b46a74289/part-00000-14906465-d144-4018-9da2-1419f149e924-c000.snappy.parquet?st=2025-04-20T08%3A01%3A42Z&sv=2020-02-10&ske=2025-04-20T09%3A55%3A48Z&sig=HVH9sV4ZJD2IL79/gjJV8DZkxLNX6y91pk/OKzxo2zo%3D&sktid=dffc7209-99bc-4c37-982b-108bdc26937b&se=2025-04-20T09%3A11%3A42Z&skoid=0d80761e-e2ab-4960-a229-12d5109726e1&spr=https&sks=b&skt=2025-04-20T07%3A55%3A48Z&sp=r&scid=8d01607d-608f-400b-b329-51be08112873&skv=2025-01-05&sr=b","expirationTimestamp":1745140302676,"id":"1ca5eccdbb8c4a4035dc2fa3ae2f7210","partitionValues":{},"size":1520655,"stats":"{\"numRecords\":3293,\"minValues\":{\"id\":\"206640_00097D297556E42E98B755867\",\"date\":1537688048367,\"geo\":\"\",\"linkedid\":\"\",\"linkedtable\":\"\",\"name\":\"\",\"owner\":\"206640_01-10 Resident\",\"projectid\":\"\",\"status\":-2,\"history\":\"\",\"templateid\":\"206640_0077349A19C8FFED85F2BE2E5\",\"value\":\"{\\\"F1\\\":\\\"\\\",\\\"F2\\\":\\\"\\\",\\\"F3\\\":\\\"\\\",\\\"F4\\\":\\\"\\\"\",\"module\":\"Activity\",\"feature\":\"Activity Form\"},\"maxValues\":{\"id\":\"206640_fed5662d608d5154\",\"date\":1743387947144,\"geo\":\"92.190,24.711\",\"linkedid\":\"206640_fed5662d4a679a7a\",\"linkedtable\":\"novadetrack.units\",\"name\":\"[NEW]\",\"owner\":\"206640_webinardemo\",\"projectid\":\"206640_ZZOSI\",\"status\":300,\"history\":\"[{\\\"name\\\":\\\"Work In Progress\\\",\\\"sta\",\"templateid\":\"206640_fa9c1930-aeae-11ed-bca4-0\",\"value\":\"{}\",\"module\":\"Safety\",\"feature\":\"Weekly Permit to Work\"},\"nullCount\":{\"id\":0,\"date\":0,\"geo\":0,\"linkedid\":0,\"linkedtable\":0,\"name\":0,\"owner\":0,\"projectid\":0,\"status\":0,\"history\":0,\"templateid\":0,\"value\":0,\"module\":1522,\"feature\":1522}}"}}
# {"file":{"url":"https://asiadatastorage.dfs.core.windows.net/metastore/0f7c5957-12d6-4931-a13f-6e65314456b6/tables/9959bcb6-510a-480a-9d0b-102b46a74289/part-00001-c6aa9584-652b-43bb-b9d2-d106ef5ed82c-c000.snappy.parquet?st=2025-04-20T08%3A01%3A42Z&sv=2020-02-10&ske=2025-04-20T09%3A55%3A48Z&sig=MeJK/NMwlAnwnEdgSLjIs75y0eKabHf4dYptrF107R0%3D&sktid=dffc7209-99bc-4c37-982b-108bdc26937b&se=2025-04-20T09%3A11%3A42Z&skoid=0d80761e-e2ab-4960-a229-12d5109726e1&spr=https&sks=b&skt=2025-04-20T07%3A55%3A48Z&sp=r&scid=8d01607d-608f-400b-b329-51be08112873&skv=2025-01-05&sr=b","expirationTimestamp":1745140302676,"id":"69d04e0485621cf88ab1454a976bcd98","partitionValues":{},"size":1525719,"stats":"{\"numRecords\":2823,\"minValues\":{\"id\":\"206640_00AFD12080CD09022E7E9E214\",\"date\":1543830084603,\"geo\":\"\",\"linkedid\":\"\",\"linkedtable\":\"\",\"name\":\"\",\"owner\":\"206640_Adrian Lee\",\"projectid\":\"\",\"status\":-2,\"history\":\"\",\"templateid\":\"206640_005454872D5E9622B9A707B98\",\"value\":\"{\\\"F1\\\":\\\"\\\",\\\"F2\\\":\\\"Shini\\\",\\\"F3\\\":\\\"\\\",\\\"F\",\"module\":\"Activity\",\"feature\":\"Activity Form\"},\"maxValues\":{\"id\":\"206640_ffe1e9c87576f74\",\"date\":1743386190992,\"geo\":\"95.238,51.961\",\"linkedid\":\"206640_fed5662d87a2291d:F26\",\"linkedtable\":\"novadetrack.units\",\"name\":\"test induction 123\",\"owner\":\"206640_sanjay\",\"projectid\":\"206640_ZZOSI\",\"status\":300,\"history\":\"[{\\\"name\\\":\\\"Work In Progress\\\",\\\"sta\",\"templateid\":\"206640_fa9c1930-aeae-11ed-bca4-0\",\"value\":\"{}\",\"module\":\"Safety\",\"feature\":\"Weekly Permit to Work\"},\"nullCount\":{\"id\":0,\"date\":0,\"geo\":0,\"linkedid\":0,\"linkedtable\":0,\"name\":0,\"owner\":0,\"projectid\":0,\"status\":0,\"history\":0,\"templateid\":0,\"value\":0,\"module\":1298,\"feature\":1298}}"}}
# {"file":{"url":"https://asiadatastorage.dfs.core.windows.net/metastore/0f7c5957-12d6-4931-a13f-6e65314456b6/tables/9959bcb6-510a-480a-9d0b-102b46a74289/part-00002-90358bfa-d740-4fd6-b15d-288f7c1b12a7-c000.snappy.parquet?st=2025-04-20T08%3A01%3A42Z&sv=2020-02-10&ske=2025-04-20T09%3A55%3A48Z&sig=hY%2Besj4hrkz6uCIRLnh%2BY1wl%2BuI2CNO5ju05tWa3ZHU%3D&sktid=dffc7209-99bc-4c37-982b-108bdc26937b&se=2025-04-20T09%3A11%3A42Z&skoid=0d80761e-e2ab-4960-a229-12d5109726e1&spr=https&sks=b&skt=2025-04-20T07%3A55%3A48Z&sp=r&scid=8d01607d-608f-400b-b329-51be08112873&skv=2025-01-05&sr=b","expirationTimestamp":1745140302676,"id":"1a3cadc5e5d30a1d3363d2aa81a1bd47","partitionValues":{},"size":1507753,"stats":"{\"numRecords\":3100,\"minValues\":{\"id\":\"206640_000E64CB37B1802451BF676B2\",\"date\":1540949572334,\"geo\":\"\",\"linkedid\":\"\",\"linkedtable\":\"\",\"name\":\"\",\"owner\":\"206640_Adrian Lee\",\"projectid\":\"\",\"status\":-2,\"history\":\"\",\"templateid\":\"206640_0077349A19C8FFED85F2BE2E5\",\"value\":\"{\\\"\\\":\\\"wer\\\"}\",\"module\":\"Activity\",\"feature\":\"Activity Form\"},\"maxValues\":{\"id\":\"206640_fe0911c8b5f4557\",\"date\":1743387599860,\"geo\":\"94.847,29.735\",\"linkedid\":\"206640_fc3a9caa5686378\",\"linkedtable\":\"novadetrack.units\",\"name\":\"undefined/S\",\"owner\":\"206640_sanjay\",\"projectid\":\"206640_ZZOSI\",\"status\":300,\"history\":\"[{\\\"name\\\":\\\"Work In Progress\\\",\\\"sta\",\"templateid\":\"206640_fa9c1930-aeae-11ed-bca4-0\",\"value\":\"{}\",\"module\":\"Safety\",\"feature\":\"Weekly Permit to Work\"},\"nullCount\":{\"id\":0,\"date\":0,\"geo\":0,\"linkedid\":0,\"linkedtable\":0,\"name\":0,\"owner\":0,\"projectid\":0,\"status\":0,\"history\":0,\"templateid\":0,\"value\":0,\"module\":1442,\"feature\":1442}}"}}
# {"file":{"url":"https://asiadatastorage.dfs.core.windows.net/metastore/0f7c5957-12d6-4931-a13f-6e65314456b6/tables/9959bcb6-510a-480a-9d0b-102b46a74289/part-00003-57c9b749-1942-4e80-8bad-3f71e323d218-c000.snappy.parquet?st=2025-04-20T08%3A01%3A42Z&sv=2020-02-10&ske=2025-04-20T09%3A55%3A48Z&sig=sdEXk3iS/2JmqdME68df6Q23G7SDT1YpEeWfSNmXWm4%3D&sktid=dffc7209-99bc-4c37-982b-108bdc26937b&se=2025-04-20T09%3A11%3A42Z&skoid=0d80761e-e2ab-4960-a229-12d5109726e1&spr=https&sks=b&skt=2025-04-20T07%3A55%3A48Z&sp=r&scid=8d01607d-608f-400b-b329-51be08112873&skv=2025-01-05&sr=b","expirationTimestamp":1745140302677,"id":"f210dff226cc020a27b7d59a761a603d","partitionValues":{},"size":1471235,"stats":"{\"numRecords\":3092,\"minValues\":{\"id\":\"206640_002F92E05055877C7EF4378C0\",\"date\":1537754640946,\"geo\":\"\",\"linkedid\":\"\",\"linkedtable\":\"\",\"name\":\"\",\"owner\":\"206640_Adrian Lee\",\"projectid\":\"\",\"status\":-2,\"history\":\"\",\"templateid\":\"206640_0077349A19C8FFED85F2BE2E5\",\"value\":\"{\\\"F1\\\":\\\"\\\",\\\"F2\\\":\\\"\\\",\\\"F3\\\":\\\"\\\",\\\"F4\\\":\\\"\\\"\",\"module\":\"Activity\",\"feature\":\"Activity Form\"},\"maxValues\":{\"id\":\"206640_fed5662d6dde409d\",\"date\":1743391141330,\"geo\":\"93.600,29.976\",\"linkedid\":\"206640_ffa977e543ee745\",\"linkedtable\":\"novadetrack.units\",\"name\":\"tom\",\"owner\":\"206640_sanjay\",\"projectid\":\"206640_ZZOSI\",\"status\":300,\"history\":\"[{\\\"name\\\":\\\"重复\\\",\\\"note\\\":\\\"bb434bac04\",\"templateid\":\"206640_fa9c1930-aeae-11ed-bca4-0\",\"value\":\"{}\",\"module\":\"Safety\",\"feature\":\"Weekly Permit to Work\"},\"nullCount\":{\"id\":0,\"date\":0,\"geo\":0,\"linkedid\":0,\"linkedtable\":0,\"name\":0,\"owner\":0,\"projectid\":0,\"status\":0,\"history\":0,\"templateid\":0,\"value\":0,\"module\":1409,\"feature\":1409}}"}}
# {"file":{"url":"https://asiadatastorage.dfs.core.windows.net/metastore/0f7c5957-12d6-4931-a13f-6e65314456b6/tables/9959bcb6-510a-480a-9d0b-102b46a74289/part-00000-39c85c0d-62c6-446c-b1ab-a85970ceb6ed-c000.snappy.parquet?st=2025-04-20T08%3A01%3A42Z&sv=2020-02-10&ske=2025-04-20T09%3A55%3A48Z&sig=diwQbYFEc1obd4pYUbAnw7gEYD9JatjWQI6H6AUCo/Q%3D&sktid=dffc7209-99bc-4c37-982b-108bdc26937b&se=2025-04-20T09%3A11%3A42Z&skoid=0d80761e-e2ab-4960-a229-12d5109726e1&spr=https&sks=b&skt=2025-04-20T07%3A55%3A48Z&sp=r&scid=8d01607d-608f-400b-b329-51be08112873&skv=2025-01-05&sr=b","expirationTimestamp":1745140302677,"id":"733d8e28b767ac3973819a9f9e74d150","partitionValues":{},"size":8810,"stats":"{\"numRecords\":9,\"minValues\":{\"id\":\"206640_2db08b9702a0fd13\",\"date\":1743522100903,\"geo\":\"\",\"linkedid\":\"206640_1DC722082F2342A5AD27D6BC9\",\"linkedtable\":\"novadetrack.inspections\",\"name\":\"251\",\"owner\":\"206640_Angela1\",\"projectid\":\"206640_14\",\"status\":0,\"history\":\"\",\"templateid\":\"206640_82787FD2FF8B842AF003FBEBF\",\"value\":\"{\\\"F15\\\":\\\"1\\\",\\\"F17\\\":\\\"1\\\",\\\"F24\\\":\\\"1\\\",\\\"\",\"module\":\"Safety\",\"feature\":\"Safety Form\"},\"maxValues\":{\"id\":\"206640_be60bbe7b6e9e7ce\",\"date\":1743560539604,\"geo\":\"14.583532,121.177559\",\"linkedid\":\"206640_9F3DA49EA8F8070B713176927\",\"linkedtable\":\"novadetrack.units\",\"name\":\"TEH-CONS-146\",\"owner\":\"206640_Ramie\",\"projectid\":\"206640_4HXD9I\",\"status\":100,\"history\":\"[{\\\"name\\\":\\\"Work In Progress\\\",\\\"sta\",\"templateid\":\"206640_D182E35C725B5AE96C728CE91\",\"value\":\"{\\\"insp_schedule_date\\\":1743557439\",\"module\":\"Safety\",\"feature\":\"Safety Form\"},\"nullCount\":{\"id\":0,\"date\":0,\"geo\":0,\"linkedid\":0,\"linkedtable\":0,\"name\":0,\"owner\":0,\"projectid\":0,\"status\":0,\"history\":0,\"templateid\":0,\"value\":0,\"module\":2,\"feature\":2}}"}}
# {"file":{"url":"https://asiadatastorage.dfs.core.windows.net/metastore/0f7c5957-12d6-4931-a13f-6e65314456b6/tables/9959bcb6-510a-480a-9d0b-102b46a74289/part-00001-9c61d719-f674-4069-b1e8-7eaf28e9efd7-c000.snappy.parquet?st=2025-04-20T08%3A01%3A42Z&sv=2020-02-10&ske=2025-04-20T09%3A55%3A48Z&sig=SC8yfvA2odXtNaG90t8kDIFfWsYTVCrmAMagIFWvKfE%3D&sktid=dffc7209-99bc-4c37-982b-108bdc26937b&se=2025-04-20T09%3A11%3A42Z&skoid=0d80761e-e2ab-4960-a229-12d5109726e1&spr=https&sks=b&skt=2025-04-20T07%3A55%3A48Z&sp=r&scid=8d01607d-608f-400b-b329-51be08112873&skv=2025-01-05&sr=b","expirationTimestamp":1745140302677,"id":"fe167a90a32235c60842ec7be13183fd","partitionValues":{},"size":7870,"stats":"{\"numRecords\":10,\"minValues\":{\"id\":\"206640_2cd71821676a18c4\",\"date\":1742352889443,\"geo\":\"1.292193,103.851201\",\"linkedid\":\"206640_2cd71821676a18c4:F48\",\"linkedtable\":\"Forms.forms\",\"name\":\"67\",\"owner\":\"206640_Angela1\",\"projectid\":\"206640_14\",\"status\":-2,\"history\":\"\",\"templateid\":\"206640_03BBAB9A1CB2EC0F77D7828B8\",\"value\":\"{\\\"F1\\\":\\\"*Use the risk rating tabl\",\"module\":\"Safety\",\"feature\":\"Permit to Work\"},\"maxValues\":{\"id\":\"206640_be60bbe794a69e5e\",\"date\":1743561141080,\"geo\":\"69.915,76.991\",\"linkedid\":\"206640_BA736D108E3E43AD5E9402044\",\"linkedtable\":\"novadetrack.units\",\"name\":\"TEH-CONSA030301-005\",\"owner\":\"206640_Ludwig Facial\",\"projectid\":\"206640_4HXD9I\",\"status\":200,\"history\":\"[{\\\"name\\\":\\\"Verified\\\",\\\"staff\\\":\\\"Lud\",\"templateid\":\"206640_D182E35C725B5AE96C728CE91\",\"value\":\"{\\\"F9\\\":1743523200000,\\\"F15\\\":1,\\\"F10\",\"module\":\"Safety\",\"feature\":\"Safety Form\"},\"nullCount\":{\"id\":0,\"date\":0,\"geo\":0,\"linkedid\":0,\"linkedtable\":0,\"name\":0,\"owner\":0,\"projectid\":0,\"status\":0,\"history\":0,\"templateid\":0,\"value\":0,\"module\":2,\"feature\":2}}"}}
# {"file":{"url":"https://asiadatastorage.dfs.core.windows.net/metastore/0f7c5957-12d6-4931-a13f-6e65314456b6/tables/9959bcb6-510a-480a-9d0b-102b46a74289/part-00002-71c6a275-ba4e-4554-8011-72700ca084c8-c000.snappy.parquet?st=2025-04-20T08%3A01%3A42Z&sv=2020-02-10&ske=2025-04-20T09%3A55%3A48Z&sig=w53TX7qiLO2hZ73tQ4BkWgydVdC68ry6tf7CpJgLP%2Bs%3D&sktid=dffc7209-99bc-4c37-982b-108bdc26937b&se=2025-04-20T09%3A11%3A42Z&skoid=0d80761e-e2ab-4960-a229-12d5109726e1&spr=https&sks=b&skt=2025-04-20T07%3A55%3A48Z&sp=r&scid=8d01607d-608f-400b-b329-51be08112873&skv=2025-01-05&sr=b","expirationTimestamp":1745140302677,"id":"515dbe30b25ee3f0fbfc07149d39d818","partitionValues":{},"size":7341,"stats":"{\"numRecords\":9,\"minValues\":{\"id\":\"206640_07C71C4DEDF8349D4BC017036\",\"date\":1743154343384,\"geo\":\"\",\"linkedid\":\"206640_3617e139f1d72cd3\",\"linkedtable\":\"novadetrack.inspections\",\"name\":\"248\",\"owner\":\"206640_Noster\",\"projectid\":\"206640_4HXD9I\",\"status\":-1,\"history\":\"[{\\\"name\\\":\\\"Duplicated\\\",\\\"note\\\":\\\"11\",\"templateid\":\"206640_4B2FC5039980A1A40DFF6EAE7\",\"value\":\"{\\\"F15\\\":\\\"1\\\",\\\"F17\\\":\\\"1\\\",\\\"F22\\\":\\\"1\\\",\\\"\"},\"maxValues\":{\"id\":\"206640_BD8DB5A596C62B04084B05BF8\",\"date\":1743504806572,\"geo\":\"14.609953,121.049312\",\"linkedid\":\"206640_F2187A27C6465B81553DBA7C1\",\"linkedtable\":\"novadetrack.inspections\",\"name\":\"TEH-CONS-144\",\"owner\":\"206640_Ramie\",\"projectid\":\"206640_4HXD9I\",\"status\":200,\"history\":\"[{\\\"name\\\":\\\"Work In Progress\\\",\\\"sta\",\"templateid\":\"206640_CDD18F01B15137E5550DAE073\",\"value\":\"{\\\"insp_schedule_date\\\":1743502403\"},\"nullCount\":{\"id\":0,\"date\":0,\"geo\":0,\"linkedid\":0,\"linkedtable\":0,\"name\":0,\"owner\":0,\"projectid\":0,\"status\":0,\"history\":0,\"templateid\":0,\"value\":0,\"module\":9,\"feature\":9}}"}}
# {"file":{"url":"https://asiadatastorage.dfs.core.windows.net/metastore/0f7c5957-12d6-4931-a13f-6e65314456b6/tables/9959bcb6-510a-480a-9d0b-102b46a74289/part-00003-a9d92961-5b46-4b62-92ef-6a342e76b7e2-c000.snappy.parquet?st=2025-04-20T08%3A01%3A42Z&sv=2020-02-10&ske=2025-04-20T09%3A55%3A48Z&sig=WPf1KEiXzkBXGR8xbtLlBP4nUDBOLqgNcfwEO7aYprI%3D&sktid=dffc7209-99bc-4c37-982b-108bdc26937b&se=2025-04-20T09%3A11%3A42Z&skoid=0d80761e-e2ab-4960-a229-12d5109726e1&spr=https&sks=b&skt=2025-04-20T07%3A55%3A48Z&sp=r&scid=8d01607d-608f-400b-b329-51be08112873&skv=2025-01-05&sr=b","expirationTimestamp":1745140302677,"id":"579dfe3d618a48051559810074162bb2","partitionValues":{},"size":6883,"stats":"{\"numRecords\":10,\"minValues\":{\"id\":\"206640_0E3FD29267C948B2F7840275B\",\"date\":1742452496739,\"geo\":\"\",\"linkedid\":\"206640_27330C836BB27E3C33E276C03\",\"linkedtable\":\"novadetrack.inspections\",\"name\":\"249\",\"owner\":\"206640_Jiaqi Chien\",\"projectid\":\"206640_14\",\"status\":-1,\"history\":\"\",\"templateid\":\"206640_0C518AD7AED009D38DAFAF590\",\"value\":\"{\\\"F9\\\":1743436800000,\\\"F15\\\":\\\"0\\\",\\\"F\",\"module\":\"Safety\",\"feature\":\"Safety Form\"},\"maxValues\":{\"id\":\"206640_be60bbe773e0d87e\",\"date\":1743522100903,\"geo\":\"14.609948,121.049308\",\"linkedid\":\"206640_bc9a5d47247cdd0\",\"linkedtable\":\"novadetrack.units\",\"name\":\"TEH-CONS-145\",\"owner\":\"206640_Ramie\",\"projectid\":\"206640_4HXD9I\",\"status\":100,\"history\":\"[{\\\"name\\\":\\\"Work In Progress\\\",\\\"sta\",\"templateid\":\"206640_D182E35C725B5AE96C728CE91\",\"value\":\"{}\",\"module\":\"Safety\",\"feature\":\"Safety Form\"},\"nullCount\":{\"id\":0,\"date\":0,\"geo\":0,\"linkedid\":0,\"linkedtable\":0,\"name\":0,\"owner\":0,\"projectid\":0,\"status\":0,\"history\":0,\"templateid\":0,\"value\":0,\"module\":8,\"feature\":8}}"}}
#
# Metadata (Schema of table) {'id': '425438de-09d8-4e26-9e13-a3a585c480bd', 'format': {'provider': 'parquet'}, 'schemaString': '{"type":"struct","fields":[{"name":"id","type":"string","nullable":false,"metadata":{}},{"name":"date","type":"long","nullable":true,"metadata":{}},{"name":"geo","type":"string","nullable":true,"metadata":{}},{"name":"linkedid","type":"string","nullable":true,"metadata":{}},{"name":"linkedtable","type":"string","nullable":true,"metadata":{}},{"name":"name","type":"string","nullable":true,"metadata":{}},{"name":"owner","type":"string","nullable":true,"metadata":{}},{"name":"projectid","type":"string","nullable":true,"metadata":{}},{"name":"status","type":"integer","nullable":true,"metadata":{}},{"name":"history","type":"string","nullable":true,"metadata":{}},{"name":"templateid","type":"string","nullable":true,"metadata":{}},{"name":"value","type":"string","nullable":true,"metadata":{}},{"name":"module","type":"string","nullable":true,"metadata":{}},{"name":"feature","type":"string","nullable":true,"metadata":{}}]}', 'partitionColumns': [], 'configuration': {}, 'size': 6056266, 'numFiles': 8}
# Number of rows in unybiz_forms_forms table: 12346
#                                           id           date  \
# 0      206640_00097D297556E42E98B7558677AFF2  1742390671123
# 1      206640_00AE780CADA26A315E33333BF2C304  1704690566066
# 2      206640_00B41D5E963B8369C036C0AF408BEF  1742451765478
# 3      206640_00F17EA056B781AE2F9F10387D3178  1703566363695
# 4      206640_00FD19ECE8B9CC05229F6174E0A5B2  1715928870640
# ...                                      ...            ...
# 12341                206640_583f0dbc6a5fbef7  1742452496739
# 12342  206640_C40AAA97C1D7EB92F6573715AAE65C  1743513556657
# 12343  206640_8BC84057206305CCBEFE316BD31EF4  1743513556633
# 12344                206640_be60bbe6edae5991  1743522100903
# 12345                206640_be60bbe773e0d87e  1743522100903
#
#                          geo                                   linkedid  \
# 0                             206640_2593735AD0B542774C9EF6D1715D33:F27
# 1                                 206640_765E1E07690F3AA190EE7D46A14EC4
# 2                                 206640_04D9D1EAC517053A10CE4110D7EF6C
# 3                                 206640_75C4D3669A535A84802EA3B1EEB14C
# 4                                                         206640_287411
# ...                      ...                                        ...
# 12341                                            206640_bc9a5d47247cdd0
# 12342  1.4450688,103.8286848      206640_27330C836BB27E3C33E276C03B4D12
# 12343  1.4450688,103.8286848      206640_27330C836BB27E3C33E276C03B4D12
# 12344   14.583532,121.177559      206640_765E1E07690F3AA190EE7D46A14EC4
# 12345   14.583532,121.177559      206640_765E1E07690F3AA190EE7D46A14EC4
#
#                    linkedtable                name                  owner  \
# 0                  Forms.forms                   6     206640_Jiaqi Chien
# 1            novadetrack.units           TEC-B12AB     206640_Jiaqi Chien
# 2      novadetrack.inspections             CHR-002     206640_Jiaqi Chien
# 3            novadesafety.ptws  TEH-dupA010101-002  206640_Database Admin
# 4       novaderesources.people                  17  206640_Database Admin
# ...                        ...                 ...                    ...
# 12341     novadetrack.requests        TEH-CONS-043          206640_Noster
# 12342  novadetrack.inspections                  28     206640_Jiaqi Chien
# 12343  novadetrack.inspections        TEH-CONS-018     206640_Jiaqi Chien
# 12344        novadetrack.units           TEC-B12AB   206640_Ludwig Facial
# 12345        novadetrack.units           TEC-B12AB   206640_Ludwig Facial
#
#            projectid  status  \
# 0          206640_14       0
# 1          206640_14       2
# 2           206640_3       1
# 3      206640_4HXD9I     100
# 4                          1
# ...              ...     ...
# 12341  206640_4HXD9I     100
# 12342  206640_4HXD9I       0
# 12343  206640_4HXD9I       1
# 12344      206640_14       2
# 12345      206640_14       2
#
#                                                  history  \
# 0
# 1      [{"name":"Requested by PC","staff":"Robert","d...
# 2      [{"name":"Work In Progress","staff":"Jiaqi Chi...
# 3      [{"name":"Submitted","staff":"Database Admin",...
# 4      [{"name":"Submitted","staff":"Database Admin",...
# ...                                                  ...
# 12341  [{"name":"Submitted (QP)","staff":"Noster","da...
# 12342
# 12343  [{"name":"Work In Progress","staff":"Jiaqi Chi...
# 12344  [{"name":"Sent to Rejected","staff":"Ludwig Fa...
# 12345  [{"name":"Sent to Rejected","staff":"Ludwig Fa...
#
#                                   templateid  \
# 0      206640_C697FD5A818978DA8A91D75666D10D
# 1      206640_4C9BAB99CD7D9BFBD16645F21F0162
# 2      206640_DB1B73F4E6D670347C46354B249DA9
# 3      206640_111E7726A1E2E9F6712E72A3940C48
# 4      206640_84CBF819A8DA3F2F16752AAF82EBD9
# ...                                      ...
# 12341  206640_6F5AE576902410FB0511656D9A9FEB
# 12342  206640_0C518AD7AED009D38DAFAF5906E22F
# 12343  206640_0D0D524A96DFF7E9E354BAC616BC80
# 12344  206640_D182E35C725B5AE96C728CE917FFD3
# 12345  206640_D182E35C725B5AE96C728CE917FFD3
#
#                                                    value  module  \
# 0      {"F14":"AET-182595","F15":"form id","F16":"mat...    None
# 1      {"F2":"1AF76A1EEBE635677ACA718F964525","F70":"...  Safety
# 2      {"insp_schedule_date":1742451765508,"insp_assi...    None
# 3      {"F70":"TEH-dupA010101-002","F6":"Database Adm...  Safety
# 4      {"F2":1715928870640,"F3":"Axel","F4":"Test Mai...    None
# ...                                                  ...     ...
# 12341                                                 {}    None
# 12342                                                 {}    None
# 12343  {"insp_schedule_date":1743513556678,"insp_assi...    None
# 12344           {"F9":1743436800000,"F15":"0","F10":"1"}  Safety
# 12345           {"F9":1743436800000,"F15":"0","F10":"1"}  Safety
#
#               feature
# 0                None
# 1         Safety Form
# 2                None
# 3      Permit to Work
# 4                None
# ...               ...
# 12341            None
# 12342            None
# 12343            None
# 12344     Safety Form
# 12345     Safety Form
#
# [12346 rows x 14 columns]
# Processing table: novadetrack_publicprojects
# Response text: {"protocol":{"minReaderVersion":1}}
# {"metaData":{"id":"bc20f44b-24c6-48ac-9656-3eec5546723f","format":{"provider":"parquet"},"schemaString":"{\"type\":\"struct\",\"fields\":[{\"name\":\"id\",\"type\":\"string\",\"nullable\":false,\"metadata\":{}},{\"name\":\"appids\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"code\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"name\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"address\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"phase\",\"type\":\"integer\",\"nullable\":true,\"metadata\":{}},{\"name\":\"siteid\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"dbadmin\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"options\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"custom\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"templateids\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"ptwtemplateids\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"wptwtemplateids\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"safetyFtemplateids\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"meetingtemplateids\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"pctemplateids\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"icdtemplateids\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"externalkey\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}}]}","partitionColumns":[],"configuration":{},"size":113571,"numFiles":4}}
# {"file":{"url":"https://asiadatastorage.dfs.core.windows.net/metastore/0f7c5957-12d6-4931-a13f-6e65314456b6/tables/8b6deca6-68b1-4aaa-8c7b-bc7b65aa387b/part-00000-1b337fc6-f374-4d50-b39a-7e4734bb059c-c000.snappy.parquet?st=2025-04-20T08%3A02%3A01Z&sv=2020-02-10&ske=2025-04-20T09%3A55%3A48Z&sig=eZMwjwrQUYVX7hiaziNeCVjndH8LEiWDnQhkLo5uJvY%3D&sktid=dffc7209-99bc-4c37-982b-108bdc26937b&se=2025-04-20T09%3A12%3A01Z&skoid=0d80761e-e2ab-4960-a229-12d5109726e1&spr=https&sks=b&skt=2025-04-20T07%3A55%3A48Z&sp=r&scid=8d01607d-608f-400b-b329-51be08112873&skv=2025-01-05&sr=b","expirationTimestamp":1745140321637,"id":"d7470d2a2f7c8fe80947a527991e94c7","partitionValues":{},"size":23269,"stats":"{\"numRecords\":33,\"minValues\":{\"id\":\"206640_0R9F\",\"appids\":\"novadeactivity|novadetrack\",\"code\":\"012\",\"name\":\"Activity for Fabrication & Insta\",\"address\":\"\",\"phase\":0,\"siteid\":\"\",\"dbadmin\":\"pa_presales@novade.net\",\"options\":\"{\\\"enableNCR\\\":\\\"0\\\",\\\"enablePTW\\\":\\\"0\\\"\",\"custom\":\"\",\"templateids\":\"\",\"ptwtemplateids\":\"\",\"wptwtemplateids\":\"\",\"safetyFtemplateids\":\"\",\"meetingtemplateids\":\"\",\"pctemplateids\":\"\",\"icdtemplateids\":\"\",\"externalkey\":\"\"},\"maxValues\":{\"id\":\"206640_Z3R\",\"appids\":\"novadetrack|novadesafety|novader\",\"code\":\"Warehouse\",\"name\":\"Warehouse\",\"address\":\"33 33/27 ถนน ศรีสุนทร Tambon Cho\",\"phase\":14,\"siteid\":\"206640_SOZ\",\"dbadmin\":\"pa_presales@novade.net\",\"options\":\"{\\\"zone3\\\":\\\"Zone\\\",\\\"zone2\\\":\\\"-\\\",\\\"zon\",\"custom\":\"{\\\"csp_projrefnum\\\":\\\"A1286-17003-2\",\"templateids\":\"206640_FB748F97A9EB08613878147E2\",\"ptwtemplateids\":\"206640_EFA1463CEA01BF636E5484DF8\",\"wptwtemplateids\":\"206640_7BBDA6D08C49FD8B5927D3308\",\"safetyFtemplateids\":\"206640_C66FA2FA43F186FB309263FF0\",\"meetingtemplateids\":\"206640_DA1A707E3CF470CA30BF81A45\",\"pctemplateids\":\"\",\"icdtemplateids\":\"206640_9B5E8F98ADD4C14BCAFBE3AE9\",\"externalkey\":\"Test_Helene_Project\"},\"nullCount\":{\"id\":0,\"appids\":0,\"code\":0,\"name\":0,\"address\":0,\"phase\":0,\"siteid\":0,\"dbadmin\":0,\"options\":0,\"custom\":0,\"templateids\":0,\"ptwtemplateids\":0,\"wptwtemplateids\":0,\"safetyFtemplateids\":0,\"meetingtemplateids\":0,\"pctemplateids\":0,\"icdtemplateids\":0,\"externalkey\":0}}"}}
# {"file":{"url":"https://asiadatastorage.dfs.core.windows.net/metastore/0f7c5957-12d6-4931-a13f-6e65314456b6/tables/8b6deca6-68b1-4aaa-8c7b-bc7b65aa387b/part-00001-6e79226c-4cea-4556-b027-cadb57bfad58-c000.snappy.parquet?st=2025-04-20T08%3A02%3A01Z&sv=2020-02-10&ske=2025-04-20T09%3A55%3A48Z&sig=Lu8KpBTNUfqUa7Cw4wzJ7Iu%2BIcaM/sPYHsO9I4uRefY%3D&sktid=dffc7209-99bc-4c37-982b-108bdc26937b&se=2025-04-20T09%3A12%3A01Z&skoid=0d80761e-e2ab-4960-a229-12d5109726e1&spr=https&sks=b&skt=2025-04-20T07%3A55%3A48Z&sp=r&scid=8d01607d-608f-400b-b329-51be08112873&skv=2025-01-05&sr=b","expirationTimestamp":1745140321637,"id":"ca1d2dfbac07c68ee60bb0f6db6527fb","partitionValues":{},"size":34949,"stats":"{\"numRecords\":33,\"minValues\":{\"id\":\"206640_1\",\"appids\":\"novadefm|novadesafety\",\"code\":\"\",\"name\":\"AMK N2C32A\",\"address\":\"\",\"phase\":0,\"siteid\":\"\",\"dbadmin\":\"pa_presales@novade.net\",\"options\":\"{\\\"novadetrack\\\":{\\\"utabs\\\":\\\"P|I\\\"},\\\"\",\"custom\":\"\",\"templateids\":\"\",\"ptwtemplateids\":\"\",\"wptwtemplateids\":\"\",\"safetyFtemplateids\":\"\",\"meetingtemplateids\":\"\",\"pctemplateids\":\"\",\"icdtemplateids\":\"\",\"externalkey\":\"\"},\"maxValues\":{\"id\":\"206640_ZZOSI\",\"appids\":\"novadetrack|novadesafety|novader\",\"code\":\"TEH\",\"name\":\"Water Infrastructure - P\",\"address\":\"Changi \",\"phase\":14,\"siteid\":\"206640_ZR0\",\"dbadmin\":\"pa_presales@novade.net\",\"options\":\"{\\\"zone3\\\":\\\"Lift Unit\\\",\\\"inspection\",\"custom\":\"{\\\"F7\\\":\\\"JTC\\\",\\\"F8\\\":\\\"1\\\"}\",\"templateids\":\"206640_FB748F97A9EB08613878147E2\",\"ptwtemplateids\":\"206640_FA0E452C2638A07860887919A\",\"wptwtemplateids\":\"206640_C2901A186DBBD3301A3731B25\",\"safetyFtemplateids\":\"206640_C6FEC6261C70E25F748A0DB67\",\"meetingtemplateids\":\"206640_F8F195C24B29EBDFA5810CDAA\",\"pctemplateids\":\"206640_66C196F0B23977B0714A4C210\",\"icdtemplateids\":\"206640_F23ACDBE8DF9F090AB81B6002\",\"externalkey\":\"\"},\"nullCount\":{\"id\":0,\"appids\":0,\"code\":0,\"name\":0,\"address\":0,\"phase\":0,\"siteid\":0,\"dbadmin\":0,\"options\":0,\"custom\":0,\"templateids\":0,\"ptwtemplateids\":0,\"wptwtemplateids\":0,\"safetyFtemplateids\":0,\"meetingtemplateids\":0,\"pctemplateids\":0,\"icdtemplateids\":0,\"externalkey\":0}}"}}
# {"file":{"url":"https://asiadatastorage.dfs.core.windows.net/metastore/0f7c5957-12d6-4931-a13f-6e65314456b6/tables/8b6deca6-68b1-4aaa-8c7b-bc7b65aa387b/part-00002-220c9df2-e80e-4e08-84d3-2c54383f4918-c000.snappy.parquet?st=2025-04-20T08%3A02%3A01Z&sv=2020-02-10&ske=2025-04-20T09%3A55%3A48Z&sig=OenJLi5/1Vr0sL0omWbc5RFJY7lPDyi4ICQ5JHsPqgk%3D&sktid=dffc7209-99bc-4c37-982b-108bdc26937b&se=2025-04-20T09%3A12%3A01Z&skoid=0d80761e-e2ab-4960-a229-12d5109726e1&spr=https&sks=b&skt=2025-04-20T07%3A55%3A48Z&sp=r&scid=8d01607d-608f-400b-b329-51be08112873&skv=2025-01-05&sr=b","expirationTimestamp":1745140321637,"id":"6af0208156020826cef242958e01c5e9","partitionValues":{},"size":25898,"stats":"{\"numRecords\":33,\"minValues\":{\"id\":\"206640_13HJRO\",\"appids\":\"novadeactivity\",\"code\":\"012-dup\",\"name\":\"AI Safety\",\"address\":\"\",\"phase\":0,\"siteid\":\"\",\"dbadmin\":\"pa_presales@novade.net\",\"options\":\"{\\\"novadetrack\\\":{\\\"utabs\\\":\\\"P|I\\\"},\\\"\",\"custom\":\"\",\"templateids\":\"\",\"ptwtemplateids\":\"\",\"wptwtemplateids\":\"\",\"safetyFtemplateids\":\"\",\"meetingtemplateids\":\"\",\"pctemplateids\":\"\",\"icdtemplateids\":\"\",\"externalkey\":\"\"},\"maxValues\":{\"id\":\"206640_Y6R\",\"appids\":\"novadetrack|novadetime\",\"code\":\"TEH-dup-dup\",\"name\":\"The Pre-Handover\",\"address\":\"Changi \",\"phase\":14,\"siteid\":\"206640_QC8U\",\"dbadmin\":\"pa_presales@novade.net\",\"options\":\"{\\\"zone1\\\":\\\"Site\\\",\\\"zone2\\\":\\\"\\\",\\\"zone\",\"custom\":\"{\\\"F7\\\":\\\"JTC\\\",\\\"F8\\\":\\\"1\\\"}\",\"templateids\":\"206640_FA127851A56E5853C99F35144\",\"ptwtemplateids\":\"206640_B7472F06793FB8F8A8398A442\",\"wptwtemplateids\":\"\",\"safetyFtemplateids\":\"206640_E488DC0D811D8AFE61D8E02B5\",\"meetingtemplateids\":\"206640_DA1A707E3CF470CA30BF81A45\",\"pctemplateids\":\"\",\"icdtemplateids\":\"206640_DDDA790EA464FF8408C5981BB\",\"externalkey\":\"\"},\"nullCount\":{\"id\":0,\"appids\":0,\"code\":0,\"name\":0,\"address\":0,\"phase\":0,\"siteid\":0,\"dbadmin\":0,\"options\":0,\"custom\":0,\"templateids\":0,\"ptwtemplateids\":0,\"wptwtemplateids\":0,\"safetyFtemplateids\":0,\"meetingtemplateids\":0,\"pctemplateids\":0,\"icdtemplateids\":0,\"externalkey\":0}}"}}
# {"file":{"url":"https://asiadatastorage.dfs.core.windows.net/metastore/0f7c5957-12d6-4931-a13f-6e65314456b6/tables/8b6deca6-68b1-4aaa-8c7b-bc7b65aa387b/part-00003-225df84e-67da-42fe-9aa3-b196660fd629-c000.snappy.parquet?st=2025-04-20T08%3A02%3A01Z&sv=2020-02-10&ske=2025-04-20T09%3A55%3A48Z&sig=rtUQUb5vfURo/yEVe1NnWxccnc3lZRAiWLqQn%2B4ye50%3D&sktid=dffc7209-99bc-4c37-982b-108bdc26937b&se=2025-04-20T09%3A12%3A01Z&skoid=0d80761e-e2ab-4960-a229-12d5109726e1&spr=https&sks=b&skt=2025-04-20T07%3A55%3A48Z&sp=r&scid=8d01607d-608f-400b-b329-51be08112873&skv=2025-01-05&sr=b","expirationTimestamp":1745140321638,"id":"987621277d83d3936fabe0380f7b8161","partitionValues":{},"size":29455,"stats":"{\"numRecords\":35,\"minValues\":{\"id\":\"206640_139A\",\"appids\":\"\",\"code\":\"AV-1\",\"name\":\"\",\"address\":\"\",\"phase\":0,\"siteid\":\"\",\"dbadmin\":\"pa_presales@novade.net\",\"options\":\"{\\\"novadetrack\\\":{\\\"utabs\\\":\\\"P|I\\\"},\\\"\",\"custom\":\"\",\"templateids\":\"\",\"ptwtemplateids\":\"\",\"wptwtemplateids\":\"\",\"safetyFtemplateids\":\"\",\"meetingtemplateids\":\"\",\"pctemplateids\":\"\",\"icdtemplateids\":\"\",\"externalkey\":\"\"},\"maxValues\":{\"id\":\"206640_YP0X8N\",\"appids\":\"novadetrack|novadesafety|novader\",\"code\":\"WP\",\"name\":\"mock up (unit-location tracking)\",\"address\":\"tuas singapore\",\"phase\":14,\"siteid\":\"206640_I2O\",\"dbadmin\":\"pa_presales@novade.net\",\"options\":\"{\\\"zone1\\\":\\\"Water Lines\\\",\\\"zone2\\\":\\\"\",\"custom\":\"{\\\"F7\\\":\\\"JTC\\\",\\\"F8\\\":\\\"1\\\"}\",\"templateids\":\"206640_F42A25545701DDCCB6CCCDF91\",\"ptwtemplateids\":\"206640_E803F33B0EB18DE7B936DA927\",\"wptwtemplateids\":\"206640_7BBDA6D08C49FD8B5927D3308\",\"safetyFtemplateids\":\"206640_E7387B6A6417DB36E79A4C140\",\"meetingtemplateids\":\"206640_DA1A707E3CF470CA30BF81A45\",\"pctemplateids\":\"\",\"icdtemplateids\":\"206640_D8A43FA4D2E63FC776B8CB71B\",\"externalkey\":\"\"},\"nullCount\":{\"id\":0,\"appids\":0,\"code\":0,\"name\":0,\"address\":0,\"phase\":0,\"siteid\":0,\"dbadmin\":0,\"options\":0,\"custom\":0,\"templateids\":0,\"ptwtemplateids\":0,\"wptwtemplateids\":0,\"safetyFtemplateids\":0,\"meetingtemplateids\":0,\"pctemplateids\":0,\"icdtemplateids\":0,\"externalkey\":0}}"}}
#
# Metadata (Schema of table) {'id': 'bc20f44b-24c6-48ac-9656-3eec5546723f', 'format': {'provider': 'parquet'}, 'schemaString': '{"type":"struct","fields":[{"name":"id","type":"string","nullable":false,"metadata":{}},{"name":"appids","type":"string","nullable":true,"metadata":{}},{"name":"code","type":"string","nullable":true,"metadata":{}},{"name":"name","type":"string","nullable":true,"metadata":{}},{"name":"address","type":"string","nullable":true,"metadata":{}},{"name":"phase","type":"integer","nullable":true,"metadata":{}},{"name":"siteid","type":"string","nullable":true,"metadata":{}},{"name":"dbadmin","type":"string","nullable":true,"metadata":{}},{"name":"options","type":"string","nullable":true,"metadata":{}},{"name":"custom","type":"string","nullable":true,"metadata":{}},{"name":"templateids","type":"string","nullable":true,"metadata":{}},{"name":"ptwtemplateids","type":"string","nullable":true,"metadata":{}},{"name":"wptwtemplateids","type":"string","nullable":true,"metadata":{}},{"name":"safetyFtemplateids","type":"string","nullable":true,"metadata":{}},{"name":"meetingtemplateids","type":"string","nullable":true,"metadata":{}},{"name":"pctemplateids","type":"string","nullable":true,"metadata":{}},{"name":"icdtemplateids","type":"string","nullable":true,"metadata":{}},{"name":"externalkey","type":"string","nullable":true,"metadata":{}}]}', 'partitionColumns': [], 'configuration': {}, 'size': 113571, 'numFiles': 4}
# Number of rows in novadetrack_publicprojects table: 134
#                 id                                             appids    code  \
# 0         206640_6                                           novadefm     MAG
# 1         206640_8                               novadefm|novadetrack     SFD
# 2        206640_16                                           novadefm      FT
# 3        206640_17                         novadeactivity|novadetrack     IDR
# 4        206640_27                                     novadeprojects     K02
# ..             ...                                                ...     ...
# 129  206640_DARLSH  novadetrack|novadeprojects|novadereports|novad...  DC-YTL
# 130    206640_WXMO  novadetrack|novadeprojects|novadereports|novad...  RW-YTL
# 131    206640_WV35  novadereports|novadeactivity|novadetime|novade...   WATER
# 132   206640_F1974                                        novadetrack     S&C
# 133     206640_JUM                                                        TFD
#
#                                               name  \
# 0                                          FM Demo
# 1                                  Global Cleaning
# 2                                   Luxury Resort
# 3                                      Renovation
# 4                                Process Reporting
# ..                                             ...
# 129          Industrial Building Construction - DC
# 130                   Railway Construction Project
# 131  Water Pipelines\r\n& Infrastructure Solutions
# 132                            System & Component
# 133
#
#                                                address  phase         siteid  \
# 0                                                           0       206640_6
# 1                                                           0   206640_ED8E2
# 2    33 33/27 ถนน ศรีสุนทร Tambon Choeng Thale, Tha...      0  206640_6V2UT9
# 3                                                           0      206640_21
# 4                                                           0      206640_20
# ..                                                 ...    ...            ...
# 129                                                         0
# 130                                                         0       206640_4
# 131                                                         0    206640_E3L7
# 132                                                         0
# 133                                                         0
#
#                     dbadmin  \
# 0    pa_presales@novade.net
# 1    pa_presales@novade.net
# 2    pa_presales@novade.net
# 3    pa_presales@novade.net
# 4    pa_presales@novade.net
# ..                      ...
# 129  pa_presales@novade.net
# 130  pa_presales@novade.net
# 131  pa_presales@novade.net
# 132  pa_presales@novade.net
# 133  pa_presales@novade.net
#
#                                                options custom  \
# 0    {"enableNCR":"0","enablePTW":"0","enableSafety...
# 1    {"zone1":"Country","zone2":"City","zone3":"Gri...
# 2    {"projNCRAfterFolderId":"","projectcenter":{"t...
# 3    {"enableUnitView":"1","zone1":"Project","zone2...
# 4    {"projNCRAfterFolderId":"E845597E4E0795DF6C867...
# ..                                                 ...    ...
# 129  {"unitLu":"Q","zone1":"Block / Building","zone...
# 130  {"unitLu":"Q","novadetrack":{"utabs":"P|I|F|In...
# 131  {"zone1":"Water Lines","zone2":"KM","zone3":"U...
# 132  {"novadetrack":{"utabs":"P|I|F|Insp","formsCou...
# 133                    {"novadetrack":{"utabs":"P|I"}}
#
#                                            templateids ptwtemplateids  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...            ...
# 129  206640_9B65C67D68EEF93F581099709775EC|206640_D...
# 130  206640_F42A25545701DDCCB6CCCDF91A2B37|206640_5...
# 131  206640_340B8AA804306C3E9C2C926F6A091D|206640_F...
# 132  206640_69E41E4737B385717608BCFC40DE98|206640_D...
# 133
#
#     wptwtemplateids safetyFtemplateids meetingtemplateids pctemplateids  \
# 0
# 1
# 2
# 3
# 4
# ..              ...                ...                ...           ...
# 129
# 130
# 131
# 132
# 133
#
#     icdtemplateids externalkey
# 0
# 1
# 2
# 3
# 4
# ..             ...         ...
# 129
# 130
# 131
# 132
# 133
#
# [134 rows x 18 columns]

# %% [markdown]
# ## Part 2
# Excited, your manager takes you to the side:
#
# > It wasn't cheap getting our forms digitised... but it's worth it - we finally have all our data in one place!
# >
# > Analyse this data and give us some suggestions to help the business, the bigger the impact the better!
#
# Analyse the two tables `forms_df` and `projects_df`, covering:
# - Business Use Case (Anything you want, but should be business relevant)
# - Analysis (e.g. EDA, Data Cleaning, ML methods, BI tools, Visualisations)
# - Suggestions (e.g. Actionables, Future Work)
#
# Code has been provided to generate the two tables regardless of whether you completed Part 1.

# %%
# Load the sharing client (save the share in the same directory as this notebook)
profile_file = "config_interview.share"
client = delta_sharing.SharingClient(profile_file)

# Load the tables
form_table_url = f"{profile_file}#interview.demo.unybiz_forms_forms"
project_table_url = f"{profile_file}#interview.demo.novadetrack_publicprojects"

# Convert to pandas DataFrames
forms_df = delta_sharing.load_as_pandas(form_table_url)
projects_df = delta_sharing.load_as_pandas(project_table_url)

# %%
forms_df.describe()
# Out:
#                                 date        status
# count                          12346  12346.000000
# mean   2023-05-20 00:37:39.312124416     27.778957
# min       2018-09-23 07:34:08.367000     -2.000000
# 25%    2022-08-01 09:46:18.353000192      0.000000
# 50%    2023-08-11 09:10:02.215000064      1.000000
# 75%    2024-06-26 09:56:42.238749952      3.000000
# max       2025-04-02 02:32:21.080000    300.000000
# std                              NaN     66.168638

# %%
projects_df.describe()
# Out:
#             phase
# count  134.000000
# mean     5.216418
# std      6.328551
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%     12.000000
# max     14.000000

# %% [markdown]
# ## Data Cleaning

# %%
# Convert 'date' to readable datetime if needed
forms_df['date'] = pd.to_datetime(forms_df['date'], unit='ms', errors='coerce')


# Parsing from history infor

def parse_history(row):
    try:
        history = json.loads(row['history']) if isinstance(row['history'], str) else []
        form_id = row['id']
        steps = []
        for i, step in enumerate(history):
            step_name = step.get('name')
            staff = step.get('staff')
            timestamp = step.get('date')
            dt = datetime.fromtimestamp(int(timestamp)/1000) if timestamp else None

            # Duration from previous step
            if i > 0:
                prev_ts = int(history[i-1].get('date', 0))
                duration = (int(timestamp) - prev_ts)/1000/3600
            else:
                duration = None

            steps.append({
                'form_id': form_id,
                'form_status': step_name,
                'staff': staff,
                'form_date': dt,
                'process_duration': duration
            })
        return steps
    except:
        return []


#Parsing from geo infor

def extract_lat_lon(geo):
    try:
        if isinstance(geo, str) and ',' in geo:
            lat, lon = map(float, geo.split(','))
            return pd.Series({'latitude': lat, 'longitude': lon})
    except:
        pass
    return pd.Series({'latitude': None, 'longitude': None})

# %%
history_data = forms_df.apply(parse_history, axis=1).explode().dropna()
history_df = pd.DataFrame(history_data.tolist())
history_df['process_duration'] = history_df['process_duration'].round(2)

# %%
geo_split = forms_df['geo'].apply(extract_lat_lon)

# %%
forms_df_clean = pd.concat([forms_df, history_df], axis=1)
forms_df_clean = pd.concat([forms_df_clean, geo_split], axis=1)
forms_df_clean.drop(['history', 'value', 'owner', 'geo'], axis=1, inplace=True)

# %%
forms_df_clean.head()
# Out:
#                                       id                    date geo  \
# 0  206640_00097D297556E42E98B7558677AFF2 2025-03-19 13:24:31.123
# 1  206640_00AE780CADA26A315E33333BF2C304 2024-01-08 05:09:26.066
# 2  206640_00B41D5E963B8369C036C0AF408BEF 2025-03-20 06:22:45.478
# 3  206640_00F17EA056B781AE2F9F10387D3178 2023-12-26 04:52:43.695
# 4  206640_00FD19ECE8B9CC05229F6174E0A5B2 2024-05-17 06:54:30.640
#
#                                     linkedid              linkedtable  \
# 0  206640_2593735AD0B542774C9EF6D1715D33:F27              Forms.forms
# 1      206640_765E1E07690F3AA190EE7D46A14EC4        novadetrack.units
# 2      206640_04D9D1EAC517053A10CE4110D7EF6C  novadetrack.inspections
# 3      206640_75C4D3669A535A84802EA3B1EEB14C        novadesafety.ptws
# 4                              206640_287411   novaderesources.people
#
#                  name      projectid  status  \
# 0                   6      206640_14     0.0
# 1           TEC-B12AB      206640_14     2.0
# 2             CHR-002       206640_3     1.0
# 3  TEH-dupA010101-002  206640_4HXD9I   100.0
# 4                  17                    1.0
#
#                               templateid  module         feature  \
# 0  206640_C697FD5A818978DA8A91D75666D10D    None            None
# 1  206640_4C9BAB99CD7D9BFBD16645F21F0162  Safety     Safety Form
# 2  206640_DB1B73F4E6D670347C46354B249DA9    None            None
# 3  206640_111E7726A1E2E9F6712E72A3940C48  Safety  Permit to Work
# 4  206640_84CBF819A8DA3F2F16752AAF82EBD9    None            None
#
#                                  form_id       form_status           staff  \
# 0  206640_00AE780CADA26A315E33333BF2C304   Requested by PC          Robert
# 1  206640_00AE780CADA26A315E33333BF2C304  Pending Approval      Subcon AUS
# 2  206640_00AE780CADA26A315E33333BF2C304        Duplicated     Jiaqi Chien
# 3  206640_00B41D5E963B8369C036C0AF408BEF  Work In Progress     Jiaqi Chien
# 4  206640_00F17EA056B781AE2F9F10387D3178         Submitted  Database Admin
#
#                 form_date  process_duration  latitude  longitude
# 0 2022-02-22 02:56:03.702               NaN       NaN        NaN
# 1 2022-02-22 03:04:33.151              0.14       NaN        NaN
# 2 2024-01-08 05:09:26.010          16442.08       NaN        NaN
# 3 2025-03-20 06:22:53.655               NaN       NaN        NaN
# 4 2023-12-26 04:53:50.414               NaN       NaN        NaN

# %%
# Cleaning data for projects_df

# Parse json values

def parse_options(row):
    try:
        opts = json.loads(row['options']) if pd.notnull(row['options']) else {}
    except Exception:
        opts = {}

    output = {
        'enableNCR': opts.get('enableNCR', None),
        'enablePTW': opts.get('enablePTW', None),
        'enableSafety': opts.get('enableSafety', None),
        'zone1': opts.get('zone1', None),
        'zone2': opts.get('zone2', None),
        'zone3': opts.get('zone3', None),
    }

    return pd.Series(output)


MAX_TEMPLATE_COLS = 5

def split_templateids(val):
    if pd.isnull(val):
        return []
    return val.split('|')

# %%
template_split_df = projects_df['templateids'].apply(split_templateids)
parse_projects_df = projects_df.apply(parse_options, axis=1)

# %%
template_split_df = template_split_df.apply(
    lambda x: x + [None]*(MAX_TEMPLATE_COLS - len(x)) if len(x) < MAX_TEMPLATE_COLS else x[:MAX_TEMPLATE_COLS]
)


template_cols = [f'templateid_{i+1}' for i in range(MAX_TEMPLATE_COLS)]
template_df = pd.DataFrame(template_split_df.tolist(), columns=template_cols)


projects_df_clean = pd.concat([projects_df, template_df, parse_projects_df], axis=1)

# %%
projects_df_clean.drop(['options','templateids'], axis=1, inplace=True)

# %%
projects_df_clean.columns
# Out:
# Index(['id', 'appids', 'code', 'name', 'address', 'phase', 'siteid', 'dbadmin',
#        'custom', 'ptwtemplateids', 'wptwtemplateids', 'safetyFtemplateids',
#        'meetingtemplateids', 'pctemplateids', 'icdtemplateids', 'externalkey',
#        'templateid_1', 'templateid_2', 'templateid_3', 'templateid_4',
#        'templateid_5', 'enableNCR', 'enablePTW', 'enableSafety', 'zone1',
#        'zone2', 'zone3'],
#       dtype='object')

# %%
projects_df_clean.to_csv('projects_df.csv', header=True)

# %%
forms_df_clean.to_csv('forms_df.csv', header=True)

# %% [markdown]
# ## Part 3
#
# Well done! Your manager is ecstatic with your analysis!
#
# She wants to have the code saved in the `Github` repository, and to have the analysis updated with new data daily.
#
# How will you achieve this?
#
# Outline the steps you would take in the `Markdown` cell below, referencing your previous experience with orchestration and version control.

# %% [markdown]
# ## Github version control

# %% [markdown]
# ## Solution for updating new data daily

# %% [markdown]
# ## Option 1: Workfow on Github Actions

# %% [markdown]
# name: Daily Update Construction Project
#
# Step 1: define when the workflow will run. i trigger the workflow to run at 11:00pm every day (UTC timezone)
# on:
#   schedule:
#     - cron: '0 23 * * *'
#
# Step 2: define jobs that will be run in this workflow. This workflow contains a single job called "daily_data_update"
# jobs:
#   daily_data_update:
#      Step 2.1: The job will run on ubuntu latest version
#     runs-on: ubuntu-latest
#      The following steps of the job will be executed in sequence
#     steps:
#        Step 2.2: Checks-out code repository under $GITHUB_WORKSPACE, so the job can access it: use specific v2 to checkout actions
#        uses: actions/checkout@v2
#
#        Step 2.3: Set up Python environment: Python environment is necessary to run this job within Github Actions workflow
#        name: Set up Python
#         uses: actions/setup-python@v2
#         with:
#           python-version: '3.10' # use a specific python version
#
#        Step 2.4: Run Data Analysis Notebook: papermill is used to run Jupyter notebook.
#        name: Run Data Analysis Notebook
#         run: |
#           pip install papermill
#           papermill interview.ipynb

# %% [markdown]
# ## Option 2: Workflow on Databricks

# %% [markdown]
# Step 1: Generate GitHub Personal Access Token from Github: GitHub settings -> Developer settings -> Personal access tokens -> Generate new token
#
# Step 2: Configure Databricks Repository:
#
# In Databricks Workspace -> Go to Repos -> Create -> select repository provider Github
# Copy URL on Github where the code is being saved on Github
# Provide GitHub Personal Access Token for authentification
# Step 3: Set up Databricks Job:
#
# In Databricks -> Go to Jobs -> Create Job -> Provide job name "Daily Update Construction Project"
# Configure Job -> In Task configuration, select Notebook Task -> Select Notebook "name_of_notebook.ipynb"
# Configure Cluster for the notebook to execute on: here is an example
# Cluster Mode: Standard
# Node Type: Standard_DS3_v2
# Number of Workers: 4 (choose autoscaling if necessary)
# Driver Node: Standard_DS3_v2
# Worker Node: Standard_DS3_v2
# Termination: Automatically terminate after 45 minutes of inactivity (optional)
# Step 4: Schedule Job:
#
# Daily at 23:00 UTC timezone
# Email notification on events of failure

# %% [markdown]
# ## Remark: The difference between Option 1 and Option 2:
#
# In Option 1, GitHub Actions workflow is executed on virtual machines provided by GitHub (e.g. ubuntu). These VMs have predefined resources and environments, and we don't need to manually configure cluster (resurces) like when we run on cloud cluster in Option 2
